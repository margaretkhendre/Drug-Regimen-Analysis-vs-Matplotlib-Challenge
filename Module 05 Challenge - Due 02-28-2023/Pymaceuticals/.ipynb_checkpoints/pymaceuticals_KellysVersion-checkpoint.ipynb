# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st


# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
study_mouse_data_complete = pd.merge(study_results, mouse_metadata, how="left",on=["Mouse ID"])
# Display the data table for preview
study_mouse_data_complete.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
mice_count= (len(study_mouse_data_complete["Mouse ID"].unique()))
mice_count
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mouse = study_mouse_data_complete.loc[study_mouse_data_complete.duplicated(subset=["Mouse ID", "Timepoint"]),"Mouse ID"].unique()
duplicate_mouse
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse_data= study_mouse_data_complete[study_mouse_data_complete["Mouse ID"].isin(duplicate_mouse)==True]
duplicate_mouse_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_study_data_complete = study_mouse_data_complete[study_mouse_data_complete["Mouse ID"].isin(duplicate_mouse)==False]
clean_study_data_complete.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
new_mice_count= (len(clean_study_data_complete["Mouse ID"].unique()))
new_mice_count
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

mean_tumor_volume= clean_study_data_complete.groupby(["Drug Regimen"]).mean()["Tumor Volume (mm3)"]
median_tumor_volume=clean_study_data_complete.groupby(["Drug Regimen"]).median()["Tumor Volume (mm3)"]
tumor_volume_variance=clean_study_data_complete.groupby(["Drug Regimen"]).var()["Tumor Volume (mm3)"]
tumor_volume_stddev=clean_study_data_complete.groupby(["Drug Regimen"]).std()["Tumor Volume (mm3)"]
tumor_volume_stderr=clean_study_data_complete.groupby(["Drug Regimen"]).sem()["Tumor Volume (mm3)"]

summary_statistics_table= pd.DataFrame({
    "Mean Tumor Volume": mean_tumor_volume,
    "Median Tumor Volume": median_tumor_volume,
    "Tumor Volume Variance": tumor_volume_variance,
    "Tumor Volume Std. Dev.": tumor_volume_stddev,
    "Tumor Volume Std. Err.": tumor_volume_stderr
    
})
summary_statistics_table
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line.
agg_summary_table= clean_study_data_complete.groupby(["Drug Regimen"]).agg({"Tumor Volume (mm3)":["mean", "median", "var", "std", "sem"]})
agg_summary_table
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

#create a dataframe for the Drug Regimen
regimenCount= clean_study_data_complete["Drug Regimen"].value_counts()

#establish the type of graph to display(bar)
regimenCount.plot(kind="bar")

#labels and values
plt.xlabel("Drug Regimen")
plt.xticks(rotation=90)
plt.ylabel("Number of Mice Tested")

plt.show()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

#x-axis
regimenCount= clean_study_data_complete["Drug Regimen"].value_counts()
x_axis= [[regimenCount]]
ticks= [x for x in x_axis]

#y axis
y_axis= [0,50,100,150,200]

#plt.bar() to generate bar chart, , alpha for opacity, align to set alignment of ticks, rotation for orientation of x axis labels
plt.bar(regimenCount.index.values,regimenCount.values,alpha=1, align= "center")

plt.xticks(rotation=90)


#labels
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice Tested")
# Out:
# Text(0, 0.5, 'Number of Mice Tested')

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

MaleFemaleCount= clean_study_data_complete["Sex"].value_counts()
MaleFemaleCount.plot(kind= "pie", autopct="%1.1f%%")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
values= (MaleFemaleCount)
labels = ["Male", "Female"]
plt.pie(values,labels=labels,autopct="%1.1f%%")
plt.title("Sex Distribution")
# Out:
# Text(0.5, 1.0, 'Sex Distribution')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
capoData= clean_study_data_complete.loc[clean_study_data_complete["Drug Regimen"]=="Capomulin"]
ramiData= clean_study_data_complete.loc[clean_study_data_complete["Drug Regimen"]=="Ramicane"]
infuData= clean_study_data_complete.loc[clean_study_data_complete["Drug Regimen"]=="Infubinol"]
ceftData= clean_study_data_complete.loc[clean_study_data_complete["Drug Regimen"]=="Ceftamin"]

# Start by getting the last (greatest) timepoint for each mouse
capoMax=capoData.groupby("Mouse ID").max()["Timepoint"]
ramiMax=ramiData.groupby("Mouse ID").max()["Timepoint"]
infuMax=infuData.groupby("Mouse ID").max()["Timepoint"]
ceftMax=ceftData.groupby("Mouse ID").max()["Timepoint"]

capoMaxDF=pd.DataFrame(capoMax)
ramiMaxDF=pd.DataFrame(ramiMax)
infuMaxDF=pd.DataFrame(infuMax)
ceftMaxDF=pd.DataFrame(ceftMax)

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
capoMerge=pd.merge(clean_study_data_complete, capoMax, how="left",on=("Mouse ID", "Timepoint"))
ramiMerge=pd.merge(clean_study_data_complete, ramiMax, how="left",on=("Mouse ID", "Timepoint"))
infuMerge=pd.merge(clean_study_data_complete, infuMax, how="left",on=("Mouse ID", "Timepoint"))
ceftMerge=pd.merge(clean_study_data_complete, ceftMax, how="left",on=("Mouse ID", "Timepoint"))

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments=["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumorVolData=[]

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
#Capomulin
capoQuartiles=capoMerge["Tumor Volume (mm3)"].quantile([.25,.5,.75])
capoLowerQ=capoQuartiles[0.25]
capoUpperQ=capoQuartiles[0.75]
capoIQR=capoUpperQ -  capoLowerQ

#Ramicane
ramiQuartiles=ramiMerge["Tumor Volume (mm3)"].quantile([.25,.5,.75])
ramiLowerQ=ramiQuartiles[0.25]
ramiUpperQ=ramiQuartiles[0.75]
ramiIQR=ramiUpperQ - ramiLowerQ

#Infubinol
infuQuartiles=infuMerge["Tumor Volume (mm3)"].quantile([.25,.5,.75])
infuLowerQ=infuQuartiles[0.25]
infuUpperQ=infuQuartiles[0.75]
infuIQR=infuUpperQ - infuLowerQ

#Ceftamin
ceftQuartiles=ceftMerge["Tumor Volume (mm3)"].quantile([.25,.5,.75])
ceftLowerQ=ceftQuartiles[0.25]
ceftUpperQ=ceftQuartiles[0.75]
ceftIQR=ceftUpperQ - ceftLowerQ
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
    #Capomulin outliers
capoLowerBound=capoLowerQ - (1.5*capoIQR)
capoUpperBound=capoUpperQ + (1.5*capoIQR)

    #Ramicane outliers
ramiLowerBound=ramiLowerQ - (1.5*ramiIQR)
ramiUpperBound=ramiUpperQ + (1.5*ramiIQR)

    #Infubinol outliers
infuLowerBound=infuLowerQ - (1.5*infuIQR)
infuUpperBound=infuUpperQ + (1.5*infuIQR)

    #Ceftamin outliers
ceftLowerBound=ceftLowerQ - (1.5*ceftIQR)
ceftUpperBound=ceftUpperQ + (1.5*ceftIQR)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
